# %%
import torch
import torch.nn as nn
import os
import sys
import numpy as np
import pandas as pd
from pathlib import Path
import glob

# ============================================================
# 1. DATA LOADING
# ============================================================

# Initialize project paths
ROOT = Path.cwd().resolve().parents[0]
sys.path.insert(0, str(ROOT))

# Define data paths
data_path = ROOT / "data" / "processed"
csv_path = data_path / "xfoil_dataset_rows.csv"

# Verify CSV file exists
if not csv_path.exists():
    raise FileNotFoundError(f"CSV file not found at: {csv_path}")

df = pd.read_csv(csv_path)
print(f"✓ CSV file loaded: {csv_path}")
print(f"✓ Data points in CSV: {len(df)}")

# If CSV is empty, read from raw txt files
if len(df) == 0:
    print("\n" + "="*60)
    print("⚠️  WARNING: CSV file is empty!")
    print("="*60)
    print("File xfoil_dataset_rows.csv is empty.")
    print("Backup: Reading raw txt files...")
    print("="*60 + "\n")

    # Read raw XFOIL polar data from txt files
    folder = ROOT / "data" / "raw" / "polars"
    files = glob.glob(str(folder / "*.txt"))
    print(f"Found {len(files)} txt files in {folder}")

    X_all = []
    Y_all = []

    # Parse each txt file (format: naca####_Re######_M##.txt)
    for file_path in files:
        filename = os.path.basename(file_path)
        parts = filename.replace(".txt", "").split("_")

        # Extract airfoil parameters from filename
        try:
            naca = float(parts[0].replace("naca", ""))
            Re = float(parts[1].replace("Re", ""))
            Mach = float(parts[2].replace("M", ""))
        except (IndexError, ValueError) as e:
            continue

        # Parse polar data from file content
        with open(file_path, "r") as f:
            for line in f:
                line = line.strip()
                if not line or line.startswith("#"):
                    continue

                parts = line.split()
                if len(parts) < 3:
                    continue

                try:
                    alpha = float(parts[0])  # Angle of attack
                    CL = float(parts[1])     # Lift coefficient
                    CD = float(parts[2])     # Drag coefficient
                except (ValueError, IndexError):
                    continue

                X_all.append([naca, Re, Mach, alpha])
                Y_all.append([CL, CD])

    X = torch.tensor(X_all, dtype=torch.float32)
    Y = torch.tensor(Y_all, dtype=torch.float32)
    print(f"✓ Loaded {len(X)} data points from txt files")

else:
    # CSV contains data
    print(f"✓ CSV columns: {list(df.columns)}")
    print(f"✓ First few rows:")
    print(df.head())

    # Convert all columns to numeric, handling any non-numeric values
    df['naca'] = pd.to_numeric(df['naca'], errors='coerce')
    df['Re'] = pd.to_numeric(df['Re'], errors='coerce')
    df['Mach'] = pd.to_numeric(df['Mach'], errors='coerce')
    df['alpha_deg'] = pd.to_numeric(df['alpha_deg'], errors='coerce')
    df['CL'] = pd.to_numeric(df['CL'], errors='coerce')
    df['CD'] = pd.to_numeric(df['CD'], errors='coerce')

    # Remove rows with missing values
    df = df.dropna(subset=['naca', 'Re', 'Mach', 'alpha_deg', 'CL', 'CD'])
    print(f"✓ After cleaning: {len(df)} data points")

    # Separate features (X) and targets (Y)
    X_all = df[['naca', 'Re', 'Mach', 'alpha_deg']].values
    Y_all = df[['CL', 'CD']].values

    X = torch.tensor(X_all, dtype=torch.float32)
    Y = torch.tensor(Y_all, dtype=torch.float32)

print(f"  X shape: {X.shape}")
print(f"  Y shape: {Y.shape}")

# ============================================================
# 2. DATA NORMALIZATION
# ============================================================
# Normalize to zero mean and unit variance for stable training

X_mean = X.mean(dim=0)
X_std = X.std(dim=0)
Y_mean = Y.mean(dim=0)
Y_std = Y.std(dim=0)

# Prevent division by zero for constant features
X_std = torch.where(X_std == 0, torch.ones_like(X_std), X_std)
Y_std = torch.where(Y_std == 0, torch.ones_like(Y_std), Y_std)

X_norm = (X - X_mean) / X_std
Y_norm = (Y - Y_mean) / Y_std

print(f"\n✓ Normalization completed")
print(f"  X_norm mean: {X_norm.mean(dim=0)}")
print(f"  X_norm std : {X_norm.std(dim=0)}")

# ============================================================
# 3. MODEL ARCHITECTURES
# ============================================================
# Define 4 different architectures for comparison

# Model 1: Baseline architecture with minimal capacity
class SmallNet(nn.Module):
    """Lightweight 2-layer network for quick training"""
    def __init__(self, input_dim=4, output_dim=2):
        super(SmallNet, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 32),
            nn.ReLU(),
            nn.Linear(32, output_dim)
        )

    def forward(self, x):
        return self.network(x)


# Model 2: Increased capacity with additional hidden layer
class MediumNet(nn.Module):
    """3-layer network with moderate capacity"""
    def __init__(self, input_dim=4, output_dim=2):
        super(MediumNet, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )

    def forward(self, x):
        return self.network(x)


# Model 3: Deeper architecture for complex pattern learning
class DeepNet(nn.Module):
    """4-layer network with high capacity"""
    def __init__(self, input_dim=4, output_dim=2):
        super(DeepNet, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, output_dim)
        )

    def forward(self, x):
        return self.network(x)


# Model 4: Regularized architecture to prevent overfitting
class DropoutNet(nn.Module):
    """3-layer network with dropout regularization"""
    def __init__(self, input_dim=4, output_dim=2, dropout=0.2):
        super(DropoutNet, self).__init__()
        self.network = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, output_dim)
        )

    def forward(self, x):
        return self.network(x)


# Instantiate all models for architecture comparison
models = {
    'small': SmallNet(input_dim=4, output_dim=2),
    'medium': MediumNet(input_dim=4, output_dim=2),
    'deep': DeepNet(input_dim=4, output_dim=2),
    'dropout': DropoutNet(input_dim=4, output_dim=2, dropout=0.2)
}

print(f"\n✓ 4 models created (not trained):")
for name, model in models.items():
    num_params = sum(p.numel() for p in model.parameters())
    print(f"  [{name:8s}] Parameters: {num_params:6d}")

# ============================================================
# 4. SAVE PREPROCESSED DATA AND MODEL METADATA
# ============================================================

save_path = data_path
os.makedirs(save_path, exist_ok=True)

# Save all data and normalization parameters for training pipeline
np.savez_compressed(
    save_path / 'data_for_training.npz',
    X=X.numpy(),
    Y=Y.numpy(),
    X_norm=X_norm.numpy(),
    Y_norm=Y_norm.numpy(),
    X_mean=X_mean.numpy(),
    X_std=X_std.numpy(),
    Y_mean=Y_mean.numpy(),
    Y_std=Y_std.numpy()
)

print(f"\n✓ Data saved: {save_path / 'data_for_training.npz'}")

# Store model architecture specifications for documentation
model_info = {
    'small': {
        'class': 'SmallNet',
        'input_dim': 4,
        'output_dim': 2,
        'layers': [32],
        'activation': "relu",
        'dropout': 0.0,
        'params': sum(p.numel() for p in models['small'].parameters())
    },
    'medium': {
        'class': 'MediumNet',
        'input_dim': 4,
        'output_dim': 2,
        'layers': [64, 64],
        'activation': "relu",
        'dropout': 0.0,
        'params': sum(p.numel() for p in models['medium'].parameters())
    },
    'deep': {
        'class': 'DeepNet',
        'input_dim': 4,
        'output_dim': 2,
        'layers': [128, 128, 64],
        'activation': "relu",
        'dropout': 0.0,
        'params': sum(p.numel() for p in models['deep'].parameters())
    },
    'dropout': {
        'class': 'DropoutNet',
        'input_dim': 4,
        'output_dim': 2,
        'layers': [64, 64],
        'activation': "relu",
        'dropout': 0.2,
        'params': sum(p.numel() for p in models['dropout'].parameters())
    }
}

np.save(save_path / 'model_info.npy', model_info)
print(f"✓ Model info saved: {save_path / 'model_info.npy'}")

print(f"\nModel comparison (number of parameters):")
for name, info in model_info.items():
    print(f"  {name:8s}: {info['params']:6d} parameters")
print(f"{'='*60}")
# Out:
# ✓ CSV file loaded: /home/markus/PyCharmMiscProject/aero-surrogate/data/processed/xfoil_dataset_rows.csv
# ✓ Data points in CSV: 22399
# ✓ CSV columns: ['naca', 'Re', 'Mach', 'Ncrit', 'alpha_deg', 'CL', 'CD']
# ✓ First few rows:
#    naca         Re  Mach  Ncrit  alpha_deg      CL       CD
# 0   615  8000000.0   0.4    9.0       -4.0 -0.5063  0.00640
# 1   615  8000000.0   0.4    9.0       -3.5 -0.4430  0.00621
# 2   615  8000000.0   0.4    9.0       -3.0 -0.3801  0.00603
# 3   615  8000000.0   0.4    9.0       -2.5 -0.3171  0.00588
# 4   615  8000000.0   0.4    9.0       -2.0 -0.2537  0.00577
# ✓ After cleaning: 22399 data points
#   X shape: torch.Size([22399, 4])
#   Y shape: torch.Size([22399, 2])
#
# ✓ Normalization completed
#   X_norm mean: tensor([ 6.1097e-08,  5.8756e-08, -2.2042e-07,  3.4061e-09])
#   X_norm std : tensor([1.0000, 1.0000, 1.0000, 1.0000])
#
# ✓ 4 models created (not trained):
#   [small   ] Parameters:    226
#   [medium  ] Parameters:   4610
# ...
